# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadHammad02/Pandas/blob/main/pandas_10_minutes_View_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
dates = pd.date_range("20130101", periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.527888  0.700433  0.841277  0.626107
# 2013-01-02  0.567355 -0.042344  0.391860  0.187388
# 2013-01-03 -0.894915  1.864874  0.917940 -1.679854
# 2013-01-04  0.347447  0.574126  0.444833  0.439887
# 2013-01-05  0.759776  1.362926 -0.916482  0.778248
# 2013-01-06 -0.260210 -1.048624  0.262653 -0.085274

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20240401"),
        "C": pd.Series(1,index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype ="int32"),
        "E": pd.Categorical(["test","train","test","train"]),
        "F": "foo",


    }
)

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2024-04-01  1.0  3   test  foo
# 1  1.0 2024-04-01  1.0  3  train  foo
# 2  1.0 2024-04-01  1.0  3   test  foo
# 3  1.0 2024-04-01  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
#view data top lines

df2.head(2)
# Out:
#      A          B    C  D      E    F
# 0  1.0 2024-04-01  1.0  3   test  foo
# 1  1.0 2024-04-01  1.0  3  train  foo

# %%
#it show bottom lines
df2.tail(2)
# Out:
#      A          B    C  D      E    F
# 2  1.0 2024-04-01  1.0  3   test  foo
# 3  1.0 2024-04-01  1.0  3  train  foo

# %%
df2.index
# Out:
# Index([0, 1, 2, 3], dtype='int64')

# %%
df2.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F'], dtype='object')

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2024-04-01 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2024-04-01 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2024-04-01 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2024-04-01 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
df2.describe()
# Out:
#          A                    B    C    D
# count  4.0                    4  4.0  4.0
# mean   1.0  2024-04-01 00:00:00  1.0  3.0
# min    1.0  2024-04-01 00:00:00  1.0  3.0
# 25%    1.0  2024-04-01 00:00:00  1.0  3.0
# 50%    1.0  2024-04-01 00:00:00  1.0  3.0
# 75%    1.0  2024-04-01 00:00:00  1.0  3.0
# max    1.0  2024-04-01 00:00:00  1.0  3.0
# std    0.0                  NaN  0.0  0.0

# %%
#Transposing your data:


df2.T
# Out:
#                      0                    1                    2  \
# A                  1.0                  1.0                  1.0
# B  2024-04-01 00:00:00  2024-04-01 00:00:00  2024-04-01 00:00:00
# C                  1.0                  1.0                  1.0
# D                    3                    3                    3
# E                 test                train                 test
# F                  foo                  foo                  foo
#
#                      3
# A                  1.0
# B  2024-04-01 00:00:00
# C                  1.0
# D                    3
# E                train
# F                  foo

# %%
#sorts by an axis

df2.sort_index(axis=1, ascending = False)
# Out:
#      F      E  D    C          B    A
# 0  foo   test  3  1.0 2024-04-01  1.0
# 1  foo  train  3  1.0 2024-04-01  1.0
# 2  foo   test  3  1.0 2024-04-01  1.0
# 3  foo  train  3  1.0 2024-04-01  1.0

# %%
#sorts by values:

df2.sort_values(by="B")
# Out:
#      A          B    C  D      E    F
# 0  1.0 2024-04-01  1.0  3   test  foo
# 1  1.0 2024-04-01  1.0  3  train  foo
# 2  1.0 2024-04-01  1.0  3   test  foo
# 3  1.0 2024-04-01  1.0  3  train  foo
