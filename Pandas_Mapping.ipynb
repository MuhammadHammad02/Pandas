# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadHammad02/Pandas/blob/main/Pandas_Mapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
s = pd.Series(['cat','cow','dog'])

# %%
s
# Out:
# 0    cat
# 1    cow
# 2    dog
# dtype: object

# %%
s.map(({'cat':"kitten",'cow':'calf'}))
# Out:
# 0    kitten
# 1      calf
# 2       NaN
# dtype: object

# %%
 data= pd.DataFrame({'Country':['Pakistan','Saudia','Turkey','Palestine','Oman'],'pop':[25,80,36,5,10]})

# %%
data
# Out:
#      Country  pop
# 0   Pakistan   25
# 1     Saudia   80
# 2     Turkey   36
# 3  Palestine    5
# 4       Oman   10

# %%
capitals = {'Oman':'Muscat','Pakistan':'Islamabad','Saudia':'Riyad','Turkey':'Ankara','Palestine':'Gaza'}

# %%
data['Capitals']=data.Country.map(capitals)

# %%
data
# Out:
#      Country  pop   Capitals
# 0   Pakistan   25  Islamabad
# 1     Saudia   80      Riyad
# 2     Turkey   36     Ankara
# 3  Palestine    5       Gaza
# 4       Oman   10     Muscat
