# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadHammad02/Pandas/blob/main/Dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Dataframe : Tabular data
#pd.Dataframe : Create a dataframe
import pandas as pd

# %%
stds = pd.DataFrame({
    'name':['Sara','Ali','Sana','Owais'],
    'age': [20,33,15,22],
    'cgpa': [3.4,2.9,3.3,4.0],
    'address': ['karachi','lahore','multan','islamabad']
})

# %%
stds
# Out:
#     name  age  cgpa    address
# 0   Sara   20   3.4    karachi
# 1    Ali   33   2.9     lahore
# 2   Sana   15   3.3     multan
# 3  Owais   22   4.0  islamabad

# %%
stds.columns
# Out:
# Index(['name', 'age', 'cgpa', 'address'], dtype='object')

# %%
stds["name"]
# Out:
# 0     Sara
# 1      Ali
# 2     Sana
# 3    Owais
# Name: name, dtype: object

# %%
stds[['name','age','cgpa']]
# Out:
#     name  age  cgpa
# 0   Sara   20   3.4
# 1    Ali   33   2.9
# 2   Sana   15   3.3
# 3  Owais   22   4.0

# %%
stds[stds['age']>20] #age greater than 20
# Out:
#     name  age  cgpa    address
# 1    Ali   33   2.9     lahore
# 3  Owais   22   4.0  islamabad

# %%
stds.age
# Out:
# 0    20
# 1    33
# 2    15
# 3    22
# Name: age, dtype: int64

# %%
import numpy as np
stds['semester'] =np.arange(1,5)

# %%
stds
# Out:
#     name  age  cgpa    address  semester
# 0   Sara   20   3.4    karachi         1
# 1    Ali   33   2.9     lahore         2
# 2   Sana   15   3.3     multan         3
# 3  Owais   22   4.0  islamabad         4

# %%
doctors = pd.DataFrame({
    'name':["Asad","Noman","Kahsan"],
    'qualification':['MS','PHD','MS']
},index=['d1','d2','d3'])

# %%
doctors
# Out:
#       name qualification
# d1    Asad            MS
# d2   Noman           PHD
# d3  Kahsan            MS

# %%
doctors["address"]= "Karachi"

# %%
doctors
# Out:
#       name qualification  address
# d1    Asad            MS  Karachi
# d2   Noman           PHD  Karachi
# d3  Kahsan            MS  Karachi

# %%
doctors.loc['d1'] #accessing row-wise data using index
# Out:
# name                Asad
# qualification         MS
# address          Karachi
# Name: d1, dtype: object

# %%
doctors.iloc[0] # accessing raw-wise data  using index location
# Out:
# name                Asad
# qualification         MS
# address          Karachi
# Name: d1, dtype: object

# %%
del doctors ['address']

# %%
doctors
# Out:
#       name qualification
# d1    Asad            MS
# d2   Noman           PHD
# d3  Kahsan            MS

# %%
stds
# Out:
#     name  age  cgpa    address  semester
# 0   Sara   20   3.4    karachi         1
# 1    Ali   33   2.9     lahore         2
# 2   Sana   15   3.3     multan         3
# 3  Owais   22   4.0  islamabad         4

# %%
stds.T # Transpose dataframe
# Out:
#                 0       1       2          3
# name         Sara     Ali    Sana      Owais
# age            20      33      15         22
# cgpa          3.4     2.9     3.3        4.0
# address   karachi  lahore  multan  islamabad
# semester        1       2       3          4

# %%
stds.values    #numpy array
# Out:
# array([['Sara', 20, 3.4, 'karachi', 1],
#        ['Ali', 33, 2.9, 'lahore', 2],
#        ['Sana', 15, 3.3, 'multan', 3],
#        ['Owais', 22, 4.0, 'islamabad', 4]], dtype=object)

# %%
stds
# Out:
#     name  age  cgpa    address  semester
# 0   Sara   20   3.4    karachi         1
# 1    Ali   33   2.9     lahore         2
# 2   Sana   15   3.3     multan         3
# 3  Owais   22   4.0  islamabad         4

# %%
stds.drop([0],axis=0) #removing specific rows from dataframe
# Out:
#     name  age  cgpa    address  semester
# 1    Ali   33   2.9     lahore         2
# 2   Sana   15   3.3     multan         3
# 3  Owais   22   4.0  islamabad         4

# %%
#Creating DataFrame with different data structure

arr = np.array([["Sarah",34,3.0,"Karachi",4],
                ["Qasim",40,3.9,"Karachi",4],
                ["Noman",45,4.0,"Karachi",2],
                ["Nadia",28,3.3,"Islamabad",3],
                ["Sonia",22,3.1,"Multan",1]])

# %%
df = pd.DataFrame(arr,columns=["Name","Age","GPA","City","Semester"])

# %%
df
# Out:
#     Name Age  GPA       City Semester
# 0  Sarah  34  3.0    Karachi        4
# 1  Qasim  40  3.9    Karachi        4
# 2  Noman  45  4.0    Karachi        2
# 3  Nadia  28  3.3  Islamabad        3
# 4  Sonia  22  3.1     Multan        1

# %%
frame =df

# %%
frame
# Out:
#     Name Age  GPA       City Semester
# 0  Sarah  34  3.0    Karachi        4
# 1  Qasim  40  3.9    Karachi        4
# 2  Noman  45  4.0    Karachi        2
# 3  Nadia  28  3.3  Islamabad        3
# 4  Sonia  22  3.1     Multan        1

# %%
employee =pd.DataFrame(
    {
    "Salary":[1000,2000,3000,4000],
    "Name":['John','Jonny','Mark','Henry']
}
    )

# %%
employee
# Out:
#    Salary   Name
# 0    1000   John
# 1    2000  Jonny
# 2    3000   Mark
# 3    4000  Henry

# %%
employee['Increment']=\
         employee['Salary'].apply(lambda salary: 50 if salary <=1000 else 25)

# %%
employee
# Out:
#    Salary   Name  Increment
# 0    1000   John         50
# 1    2000  Jonny         25
# 2    3000   Mark         25
# 3    4000  Henry         25
