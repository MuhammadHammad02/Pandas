# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadHammad02/Pandas/blob/main/Apply%2Cloc_iloc%2Cdrop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# Lets Create a dataframe of Cricket Teams

stats = pd.DataFrame(
    {
        'teams': ['Pakistan','India','Srilanka','South Africa','Newziland','Australia',"England"],
        'played':[5,4,3,5,6,5,5],
        'points':[10,8,6,7,8,9,8]
    },
    index=['t1','t2','t3','t4','t5','t6','t7']
)

# %%
stats
# Out:
#            teams  played  points
# t1      Pakistan       5      10
# t2         India       4       8
# t3      Srilanka       3       6
# t4  South Africa       5       7
# t5     Newziland       6       8
# t6     Australia       5       9
# t7       England       5       8

# %%
stats.head()
# Out:
#           teams  played  points
# 0      Pakistan       5      10
# 1         India       4       8
# 2      Srilanka       3       6
# 3  South Africa       5       7
# 4     Newziland       6       8

# %%
stats.head(3) # Displaying first three rows
# Out:
#       teams  played  points
# 0  Pakistan       5      10
# 1     India       4       8
# 2  Srilanka       3       6

# %%
stats.tail()
# Out:
#           teams  played  points
# 2      Srilanka       3       6
# 3  South Africa       5       7
# 4     Newziland       6       8
# 5     Australia       5       9
# 6       England       5       8

# %%
stats.tail(2) # displaying last two rows
# Out:
#        teams  played  points
# 5  Australia       5       9
# 6    England       5       8

# %%
stats['teams']
# Out:
# 0        Pakistan
# 1           India
# 2        Srilanka
# 3    South Africa
# 4       Newziland
# 5       Australia
# 6         England
# Name: teams, dtype: object

# %%
stats.iloc[0]
# Out:
# teams     Pakistan
# played           5
# points          10
# Name: 0, dtype: object

# %%
stats.iloc[5]
# Out:
# teams     Australia
# played            5
# points            9
# Name: 5, dtype: object

# %%
stats.iloc[1]
# Out:
# teams     India
# played        4
# points        8
# Name: 1, dtype: object

# %%
stats.values # Getting numpy array
# Out:
# array([['Pakistan', 5, 10],
#        ['India', 4, 8],
#        ['Srilanka', 3, 6],
#        ['South Africa', 5, 7],
#        ['Newziland', 6, 8],
#        ['Australia', 5, 9],
#        ['England', 5, 8]], dtype=object)

# %%
import numpy as np
stats['NO.'] = np.arange(1,8)

# %%
stats
# Out:
#            teams  played  points  NO.
# t1      Pakistan       5      10    1
# t2         India       4       8    2
# t3      Srilanka       3       6    3
# t4  South Africa       5       7    4
# t5     Newziland       6       8    5
# t6     Australia       5       9    6
# t7       England       5       8    7

# %%
stats.iloc[0:5,2]  #Specify row and then column
# Out:
# t1    10
# t2     8
# t3     6
# t4     7
# t5     8
# Name: points, dtype: int64

# %%
stats.iloc[0:5]
# Out:
#            teams  played  points  NO.
# t1      Pakistan       5      10    1
# t2         India       4       8    2
# t3      Srilanka       3       6    3
# t4  South Africa       5       7    4
# t5     Newziland       6       8    5
